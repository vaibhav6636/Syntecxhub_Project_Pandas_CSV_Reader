# %% [markdown]
# # Syntecxhub Internship
# ## Project 2 – Pandas CSV Reader & Basic Analysis
#
# ### Objective
# This project demonstrates how to:
# - Read CSV data using Pandas
# - Inspect dataset structure
# - Perform basic statistical analysis
# - Filter and manipulate data
# - Export processed results
#
# ### Tools Used
# - Python
# - Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("E:\\Data Science Intership at Syntecxhub\\Week 1\\sales_data.csv")
df
# Out:
#    OrderID Customer Region  Sales  Profit   OrderDate
# 0        1     Amit   West   5000     800  2024-01-10
# 1        2     Riya  North   7000    1200  2024-01-12
# 2        3     John   East   6500     900  2024-01-15
# 3        4    Sneha  South   4000     500  2024-01-18
# 4        5    Rahul   West   7200    1500  2024-01-20
# 5        6    Pooja  North   3000     300  2024-01-22
# 6        7    David   East   8000    2000  2024-01-25
# 7        8     Neha  South   6000    1100  2024-01-28

# %%
df.head()
# Out:
#    OrderID Customer Region  Sales  Profit   OrderDate
# 0        1     Amit   West   5000     800  2024-01-10
# 1        2     Riya  North   7000    1200  2024-01-12
# 2        3     John   East   6500     900  2024-01-15
# 3        4    Sneha  South   4000     500  2024-01-18
# 4        5    Rahul   West   7200    1500  2024-01-20

# %%
df.tail()
# Out:
#    OrderID Customer Region  Sales  Profit   OrderDate
# 3        4    Sneha  South   4000     500  2024-01-18
# 4        5    Rahul   West   7200    1500  2024-01-20
# 5        6    Pooja  North   3000     300  2024-01-22
# 6        7    David   East   8000    2000  2024-01-25
# 7        8     Neha  South   6000    1100  2024-01-28

# %%
df.info
# Out:
# <bound method DataFrame.info of    OrderID Customer Region  Sales  Profit   OrderDate
# 0        1     Amit   West   5000     800  2024-01-10
# 1        2     Riya  North   7000    1200  2024-01-12
# 2        3     John   East   6500     900  2024-01-15
# 3        4    Sneha  South   4000     500  2024-01-18
# 4        5    Rahul   West   7200    1500  2024-01-20
# 5        6    Pooja  North   3000     300  2024-01-22
# 6        7    David   East   8000    2000  2024-01-25
# 7        8     Neha  South   6000    1100  2024-01-28>

# %%
df.dtypes
# Out:
# OrderID       int64
# Customer     object
# Region       object
# Sales         int64
# Profit        int64
# OrderDate    object
# dtype: object

# %% [markdown]
# ## Data Summary & Statistical Analysis
#
# In this section, we compute:
# - Mean
# - Median
# - Minimum and Maximum values
# - Count of records
# - Overall statistical summary

# %% [markdown]
# ### Overall Statistical Summary

# %%
df.describe()
# Out:
#        OrderID        Sales       Profit
# count  8.00000     8.000000     8.000000
# mean   4.50000  5837.500000  1037.500000
# std    2.44949  1710.419748   544.944296
# min    1.00000  3000.000000   300.000000
# 25%    2.75000  4750.000000   725.000000
# 50%    4.50000  6250.000000  1000.000000
# 75%    6.25000  7050.000000  1275.000000
# max    8.00000  8000.000000  2000.000000

# %% [markdown]
# ### meean

# %%
df["Sales"].mean()
# Out:
# np.float64(5837.5)

# %%
df["Profit"].mean()
# Out:
# np.float64(1037.5)

# %% [markdown]
# ### Median

# %%
df["Sales"].median()
# Out:
# 6250.0

# %%
df["Profit"].median()
# Out:
# 1000.0

# %% [markdown]
# ### Minimum & Maximum

# %%
df["Sales"].min()
# Out:
# 3000

# %%
df["Sales"].max()
# Out:
# 8000

# %%
df["Profit"].min()
# Out:
# 300

# %%
df["Profit"].max()
# Out:
# 2000

# %% [markdown]
# ### Count of Records

# %%
df["Sales"].count()
# Out:
# np.int64(8)

# %%
len(df)
# Out:
# 8

# %% [markdown]
# ## Data Filtering and Selection
#
# In this section, we:
# - Filter rows based on conditions
# - Select specific columns
# - Create subsets of the dataset

# %% [markdown]
# ### Filter Rows (Sales greater than 6000)

# %%
high_sales = df[df["Sales"] > 6000]
high_sales
# Out:
#    OrderID Customer Region  Sales  Profit   OrderDate
# 1        2     Riya  North   7000    1200  2024-01-12
# 2        3     John   East   6500     900  2024-01-15
# 4        5    Rahul   West   7200    1500  2024-01-20
# 6        7    David   East   8000    2000  2024-01-25

# %% [markdown]
# ### Filter by Region (Example: West)

# %%
west_region = df[df["Region"] == "West"]
west_region
# Out:
#    OrderID Customer Region  Sales  Profit   OrderDate
# 0        1     Amit   West   5000     800  2024-01-10
# 4        5    Rahul   West   7200    1500  2024-01-20

# %% [markdown]
# ### Select Specific Columns

# %%
df[["Customer", "Sales", "Profit"]]
# Out:
#   Customer  Sales  Profit
# 0     Amit   5000     800
# 1     Riya   7000    1200
# 2     John   6500     900
# 3    Sneha   4000     500
# 4    Rahul   7200    1500
# 5    Pooja   3000     300
# 6    David   8000    2000
# 7     Neha   6000    1100

# %% [markdown]
# ### Filter + Select Together

# %%
df[df["Sales"] > 6000][["Customer", "Sales"]]
# Out:
#   Customer  Sales
# 1     Riya   7000
# 2     John   6500
# 4    Rahul   7200
# 6    David   8000

# %% [markdown]
# ### Row Slicing (First 3 Rows)

# %%
df.iloc[0:3]
# Out:
#    OrderID Customer Region  Sales  Profit   OrderDate
# 0        1     Amit   West   5000     800  2024-01-10
# 1        2     Riya  North   7000    1200  2024-01-12
# 2        3     John   East   6500     900  2024-01-15

# %% [markdown]
# ### Specific Row & Column using iloc

# %%
df.iloc[0, 3]
# Out:
# np.int64(5000)

# %% [markdown]
# ## Exporting Filtered Results
#
# In this section, we export processed data into:
# - CSV file
# - Excel file
#
# This demonstrates data saving and reporting capability using Pandas.

# %% [markdown]
# ### Save High Sales Data to CSV

# %%
high_sales.to_csv("high_sales_data.csv", index=False)

# %% [markdown]
# ### Save West Region Data to Excel

# %%
west_region.to_excel("west_region_data.xlsx", index=False)

# %% [markdown]
# ### Final Confirmation Print

# %%
print("Filtered files exported successfully.")
# Out:
# Filtered files exported successfully.
